# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('loan.txt')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df_women = df[df['Gender']=='Female']
df_unmarried_men = df[(df['Married']=='No') & (df['Gender']=='Male')]

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(df_women['ApplicantIncome'], df_unmarried_men['ApplicantIncome'])
# Out:
# Ttest_indResult(statistic=-1.1403012035198827, pvalue=0.2552975030762238)

# %%
df_graduate_un_men = df[(df['Married']=='No') & (df['Gender']=='Male') & (df['Education']=='Graduate')]

# %%
df_graduate_women = df[(df['Gender']=='Female') & (df['Education']=='Graduate')]

# %%
ttest_ind(df_graduate_women['ApplicantIncome'], df_graduate_un_men['ApplicantIncome'])
# Out:
# Ttest_indResult(statistic=-1.75360894634636, pvalue=0.0811185605889597)

# %%
from scipy.stats import chi2_contingency

# %% [markdown]
# We have been given a dataset containing the details of the people applied for loan.
#
# dataset: loan.csv
#
# We wish to create a new feature called 'NewFeature' using a linear combination of the features ApplicantIncome, LoanAmount and Credit_History, with weights 1, 3 and 7000,
#
# i.e., data['NewFeature'] = (data["ApplicantIncome"]) + (3 * data["LoanAmount"]) + (7000 * data["Credit_History"]).
#
# Since 'NewFeature' is a numerical feature, convert it to a categorical feature by checking whether 'NewFeature' is greater than 0.25 times the mean of 'NewFeature'. Call this feature 'Separator'.
#
# Perform a chi-square test on the contingency table formed by the features 'Loan_Status' and 'Separator' and report the p-value. Also report your interpretation.
#
# Note: Drop all the rows having 'na' values before performing any operation on the data and assume the significance level to be 5%. Also, round off the p-value to four decimal places.

# %%
df['NewFeature'] = (df["ApplicantIncome"]) + (3 * df["LoanAmount"]) + (7000 * df["Credit_History"])

# %%
nf_mean = df['NewFeature'].mean()/4

# %%
for i in range(df.shape[0]):
    if df.loc[i,'NewFeature'] < nf_mean:
        df.loc[i,'Separator'] = 0
    else:
        df.loc[i,'Separator'] = 1

# %%
df.dropna(subset = 'NewFeature', inplace = True)

# %%
df.dropna(subset = 'Loan_Status', inplace = True)

# %%
df[['Loan_Status','Separator']]
# Out:
#     Loan_Status  Separator
# 1             N        1.0
# 2             Y        1.0
# 3             Y        1.0
# 4             Y        1.0
# 5             Y        1.0
# ..          ...        ...
# 609           Y        1.0
# 610           Y        1.0
# 611           Y        1.0
# 612           Y        1.0
# 613           N        1.0
#
# [543 rows x 2 columns]

# %%
df1 = pd.crosstab(df['Separator'],df['Loan_Status'])

# %%
chi2_contingency(df1)
# Out:
# Chi2ContingencyResult(statistic=19.615753066991626, pvalue=9.468529087998976e-06, dof=1, expected_freq=array([[  4.66850829,  10.33149171],
#        [164.33149171, 363.66850829]]))

# %%
df2 = pd.crosstab(df_graduate_women['Loan_Status'],df_graduate_un_men['Loan_Status'])
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_graduate_women
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 17   LP001036  Female      No          0  Graduate            No
# 29   LP001087  Female      No          2  Graduate           NaN
# 37   LP001112  Female     Yes          0  Graduate            No
# 45   LP001137  Female      No          0  Graduate            No
# 48   LP001146  Female     Yes          0  Graduate            No
# ..        ...     ...     ...        ...       ...           ...
# 582  LP002894  Female     Yes          0  Graduate            No
# 600  LP002949  Female      No         3+  Graduate           NaN
# 604  LP002959  Female     Yes          1  Graduate            No
# 609  LP002978  Female      No          0  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 17              3510                0.0        76.0             360.0
# ...

# %%
df_graduate_un_men
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 4    LP001008   Male      No          0  Graduate            No
# 13   LP001029   Male      No          0  Graduate            No
# 15   LP001032   Male      No          0  Graduate            No
# 31   LP001095   Male      No          0  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 577  LP002874   Male      No          0  Graduate            No
# 579  LP002888   Male      No          0  Graduate           NaN
# 581  LP002893   Male      No          0  Graduate            No
# 597  LP002943   Male      No        NaN  Graduate            No
# 603  LP002958   Male      No          0  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %% [markdown]
# In the loan.csv dataset, we wish to test the hypothesis that among all loan applicants who were rejected for a loan, applicants with a credit history of 1 are more likely to be female.
#
# Use a chi-square test to verify this claim (Ensure that you drop all nan rows), and report your interpretation.
#
# Note: Use a significance level of 5%.

# %%
df = pd.read_csv('loan.txt')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df_loan_rej = df[df['Loan_Status'] == 'N']

# %%
df_loan_rej.isna().sum()
# Out:
# Loan_ID               0
# Gender                5
# Married               0
# Dependents            6
# Education             0
# Self_Employed         9
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           11
# Loan_Amount_Term      6
# Credit_History       13
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df_loan_rej.dropna(subset = ['Gender','Credit_History'], how = 'any', inplace = True)
df_loan_rej
# Out:
# C:\Users\Rhythm Shah\AppData\Local\Temp\ipykernel_28888\3512181889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loan_rej.dropna(subset = ['Gender','Credit_History'], how = 'any', inplace = True)
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 17   LP001036  Female      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 591  LP002931    Male     Yes          2      Graduate           Yes
# ...

# %%
df3 = pd.crosstab(df_loan_rej['Credit_History'], df_loan_rej['Gender'])
df3
# Out:
# Gender          Female  Male
# Credit_History
# 0.0                 16    63
# 1.0                 20    75

# %%
chi2_contingency(df3.loc[1.0])
# Out:
# Chi2ContingencyResult(statistic=0.0, pvalue=1.0, dof=0, expected_freq=array([20., 75.]))

# %% [markdown]
# In the loan.csv dataset, we wish to test the hypothesis that the loan amount payable per year is different for women and unmarried men.
#
# To do so, first define a new feature called 'Loan_Amount_per_year' using the formula 'LoanAmount' / 'Loan_Amount_Term'.
#
# Next, define group1 as the women loan applicants, and group2 as the unmarried male applicants. Print out their variances.
#
# Perform a Levene test using the median as the center to check whether the variances of the two groups are significantly different.
#
# Next, apply the t-test to check whether the average loan amount payable is significantly different for the two groups. What interpretations can be drawn from the tests conducted?
#
# Note: Assume the significance level to be 5%.

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
for i in range(df.shape[0]):
    df.loc[i,'Loan_Amount_per_year'] = df.loc[i, 'LoanAmount'] / df.loc[i, 'Loan_Amount_Term']
    
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
from scipy.stats import levene

# %%
df_women = df[df['Gender']=='Female']
df_unmarried_men = df[(df['Married']=='No') & (df['Gender']=='Male')]

# %%
df_women.dropna(subset = 'Loan_Amount_per_year',inplace = True)
df_unmarried_men.dropna(subset = 'Loan_Amount_per_year',inplace = True)
# Out:
# C:\Users\Rhythm Shah\AppData\Local\Temp\ipykernel_28888\3856847697.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_women.dropna(subset = 'Loan_Amount_per_year',inplace = True)
# C:\Users\Rhythm Shah\AppData\Local\Temp\ipykernel_28888\3856847697.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unmarried_men.dropna(subset = 'Loan_Amount_per_year',inplace = True)

# %%
levene(df_women['Loan_Amount_per_year'], df_unmarried_men['Loan_Amount_per_year'])
# Out:
# LeveneResult(statistic=0.02791644898384745, pvalue=0.8674541435146867)

# %%
ttest_ind(df_women['Loan_Amount_per_year'], df_unmarried_men['Loan_Amount_per_year'])
# Out:
# Ttest_indResult(statistic=-0.22521696710483274, pvalue=0.8220131093962639)

# %% [markdown]
# In the loan.csv dataset, we wish to test the hypothesis that among all loan applicants with a Credit_History of 1 who were rejected for a loan, the married group of people applied for a loan amount that is significantly different from the unmarried applicants.
#
# To do so, first, define group1 as the married group and group2 as the unmarried group, and retrieve their "LoanAmount" details. Drop the columns containing 'nan'.
#
# Print out their variances, and perform a Levene test to check whether the variance in the loan amount for the two groups is significantly different.
#
# Next, apply the Krushkal test to check if the median loan amount is significantly different for the two groups. What interpretations can you draw from the tests performed?
#
# Note: Assume a significance level of 5%.

# %%
df_loan_rej_ch_1 = df[(df['Loan_Status'] == 'N') & (df['Credit_History'] == 1.0)]
df_loan_rej_ch_1
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1    LP001003   Male     Yes          1      Graduate            No
# 9    LP001020   Male     Yes          1      Graduate            No
# 13   LP001029   Male      No          0      Graduate            No
# 18   LP001038   Male     Yes          0  Not Graduate            No
# 28   LP001086   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 581  LP002893   Male      No          0      Graduate            No
# 585  LP002912   Male     Yes          1      Graduate            No
# 591  LP002931   Male     Yes          2      Graduate           Yes
# 596  LP002941   Male     Yes          2  Not Graduate           Yes
# 605  LP002960   Male     Yes          0  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
df_loan_rej_ch_1.dropna(subset = 'LoanAmount', inplace = True)
df_loan_rej_ch_1
# Out:
# C:\Users\Rhythm Shah\AppData\Local\Temp\ipykernel_28888\3014818749.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loan_rej_ch_1.dropna(subset = 'LoanAmount', inplace = True)
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1    LP001003   Male     Yes          1      Graduate            No
# 9    LP001020   Male     Yes          1      Graduate            No
# 13   LP001029   Male      No          0      Graduate            No
# 18   LP001038   Male     Yes          0  Not Graduate            No
# 28   LP001086   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 574  LP002863   Male     Yes         3+      Graduate            No
# ...

# %%
levene(df_loan_rej_ch_1[df_loan_rej_ch_1['Married']=='Yes']['LoanAmount'], df_loan_rej_ch_1[df_loan_rej_ch_1['Married']=='No']['LoanAmount'])
# Out:
# LeveneResult(statistic=0.08026097081368709, pvalue=0.7776020013651652)

# %% [markdown]
# In the loan.csv dataset, we wish to test the hypothesis that among all loan applicants who were rejected for a loan, the applicant income of the people with a credit history of 1 is significantly different from the applicant income of the people with a credit history of 0.
#
# To do so, first, define group1 as the people with a credit history of 0, and group2 as the people with a credit history of 1.
#
# Retrieve their Applicant Income information and drop the columns containing 'nan'.
#
# Next, apply the Krushkal test to check whether the mean applicant income of the two groups is significantly different, and the Levene test to check if the variance in the applicant income for the two groups is significantly different. What are the results of these tests, and what interpretations can you draw?
#
# Note: Assume a significance level of 5%.

# %%
df_loan_rej_ch_0 = df[(df['Loan_Status'] == 'N') & (df['Credit_History'] == 0.0)]
df_loan_rej_ch_0
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 7    LP001014    Male     Yes         3+      Graduate            No
# 17   LP001036  Female      No          0      Graduate            No
# 20   LP001043    Male     Yes          0  Not Graduate            No
# 22   LP001047    Male     Yes          0  Not Graduate            No
# 23   LP001050     NaN     Yes          2  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 576  LP002872     NaN     Yes          0      Graduate            No
# 584  LP002911    Male     Yes          1      Graduate            No
# 589  LP002926    Male     Yes          2      Graduate           Yes
# 597  LP002943    Male      No        NaN      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df_loan_rej_ch_1 = df[(df['Loan_Status'] == 'N') & (df['Credit_History'] == 1.0)]
df_loan_rej_ch_1
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1    LP001003   Male     Yes          1      Graduate            No
# 9    LP001020   Male     Yes          1      Graduate            No
# 13   LP001029   Male      No          0      Graduate            No
# 18   LP001038   Male     Yes          0  Not Graduate            No
# 28   LP001086   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 581  LP002893   Male      No          0      Graduate            No
# 585  LP002912   Male     Yes          1      Graduate            No
# 591  LP002931   Male     Yes          2      Graduate           Yes
# 596  LP002941   Male     Yes          2  Not Graduate           Yes
# 605  LP002960   Male     Yes          0  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583             1508.0       128.0             360.0
# ...

# %%
df_loan_rej_ch_1.dropna(subset = 'ApplicantIncome', inplace = True)
df_loan_rej_ch_1
# Out:
# C:\Users\Rhythm Shah\AppData\Local\Temp\ipykernel_28888\2125230158.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loan_rej_ch_1.dropna(subset = 'ApplicantIncome', inplace = True)
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1    LP001003   Male     Yes          1      Graduate            No
# 9    LP001020   Male     Yes          1      Graduate            No
# 13   LP001029   Male      No          0      Graduate            No
# 18   LP001038   Male     Yes          0  Not Graduate            No
# 28   LP001086   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 581  LP002893   Male      No          0      Graduate            No
# ...

# %%
df_loan_rej_ch_0.dropna(subset = 'ApplicantIncome', inplace = True)
df_loan_rej_ch_0
# Out:
# C:\Users\Rhythm Shah\AppData\Local\Temp\ipykernel_28888\2262863812.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loan_rej_ch_0.dropna(subset = 'ApplicantIncome', inplace = True)
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 7    LP001014    Male     Yes         3+      Graduate            No
# 17   LP001036  Female      No          0      Graduate            No
# 20   LP001043    Male     Yes          0  Not Graduate            No
# 22   LP001047    Male     Yes          0  Not Graduate            No
# 23   LP001050     NaN     Yes          2  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 576  LP002872     NaN     Yes          0      Graduate            No
# ...

# %%
from scipy.stats import kruskal

# %%
kruskal(df_loan_rej_ch_0['ApplicantIncome'], df_loan_rej_ch_1['ApplicantIncome'])
# Out:
# KruskalResult(statistic=2.049603392395956, pvalue=0.15224584555807225)

# %%
levene(df_loan_rej_ch_0['ApplicantIncome'], df_loan_rej_ch_1['ApplicantIncome'], center = 'trimmed')
# Out:
# LeveneResult(statistic=4.939566565459423, pvalue=0.027641976971908497)

# %% [markdown]
# We believe that the loan.csv data shows that graduate unmarried men are more likely to get a loan than graduate women.
# To prove this, would a t-test be more appropriate or a chi-square test?
#
# Carry out the appropriate test on the 'Loan_Status' column for the two groups and report the p-value. Also report your interpretation.
#
# Note: Assume a confidence level of 5% and round off the p-value to 2 decimal places.

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df['gum'] = (df['Gender']=='Female') & (df['Education']=='Graduate')
df['gw'] = (df['Married']=='No') & (df['Gender']=='Male') & (df['Education']=='Graduate')

# %%
df10 = df[(df['gum']==True) | (df['gw']==True)]

# %%
df10
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0    LP001002    Male      No          0  Graduate            No
# 4    LP001008    Male      No          0  Graduate            No
# 13   LP001029    Male      No          0  Graduate            No
# 15   LP001032    Male      No          0  Graduate            No
# 17   LP001036  Female      No          0  Graduate            No
# ..        ...     ...     ...        ...       ...           ...
# 600  LP002949  Female      No         3+  Graduate           NaN
# 603  LP002958    Male      No          0  Graduate            No
# 604  LP002959  Female     Yes          1  Graduate            No
# 609  LP002978  Female      No          0  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...

# %%
pd.crosstab(df10['gw'], df10['Loan_Status'])
# Out:
# Loan_Status   N   Y
# gw
# False        31  61
# True         37  62

# %%
chi2_contingency(pd.crosstab(df10['gw'], df10['Loan_Status']))
# Out:
# Chi2ContingencyResult(statistic=0.14381605008456969, pvalue=0.7045164323229686, dof=1, expected_freq=array([[32.7539267, 59.2460733],
#        [35.2460733, 63.7539267]]))

# %% [markdown]
# In the loan.csv dataset, we wish to test the hypothesis that among all loan applicants who were rejected for a loan, applicants with a credit history of 1 are more likely to be female.
#
# Use a chi-square test to verify this claim (Ensure that you drop all nan rows), and report your interpretation.
#
# Note: Use a significance level of 5%.

# %%
df11 = df[df['Loan_Status']=='N']
df11
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 17   LP001036  Female      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 596  LP002941    Male     Yes          2  Not Graduate           Yes
# 597  LP002943    Male      No        NaN      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 605  LP002960    Male     Yes          0  Not Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df11.dropna(inplace=True)
# Out:
# C:\Users\Rhythm Shah\AppData\Local\Temp\ipykernel_28888\1559260780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df11.dropna(inplace=True)

# %%
df11
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 17   LP001036  Female      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 585  LP002912    Male     Yes          1      Graduate            No
# 589  LP002926    Male     Yes          2      Graduate           Yes
# 591  LP002931    Male     Yes          2      Graduate           Yes
# 596  LP002941    Male     Yes          2  Not Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
pd.crosstab(df11['Gender'], df11['Credit_History'])
# Out:
# Credit_History  0.0  1.0
# Gender
# Female           13   19
# Male             50   66

# %%
chi2_contingency(pd.crosstab(df11['Gender'], df11['Credit_History']))
# Out:
# Chi2ContingencyResult(statistic=0.0024123442480440483, pvalue=0.9608271544968046, dof=1, expected_freq=array([[13.62162162, 18.37837838],
#        [49.37837838, 66.62162162]]))

# %% [markdown]
# In the loan.csv dataset, we observed that among all applicants with a credit history of 1, 272 males and 53 females were granted loans, while 66 males and 19 females were not granted loans.
#
# We suspect a gender bias towards males here, and wish to test if there is any statistical significance to our claim.
#
# Perform a chi-square test to do so, and report your interpretations.
#
# Note: Assume a significance level of 5%.

# %%
df12 = df[df['Credit_History'] == 1]
df12
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df12.dropna(inplace = True)
# Out:
# C:\Users\Rhythm Shah\AppData\Local\Temp\ipykernel_28888\653449324.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12.dropna(inplace = True)

# %%
df12
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 608  LP002974    Male     Yes          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
pd.crosstab(df12['Gender'], df12['Loan_Status'])
# Out:
# Loan_Status   N    Y
# Gender
# Female       19   53
# Male         66  272

# %%
chi2_contingency(pd.crosstab(df12['Gender'], df12['Loan_Status']))
# Out:
# Chi2ContingencyResult(statistic=1.3089034809797073, pvalue=0.25259328208262877, dof=1, expected_freq=array([[ 14.92682927,  57.07317073],
#        [ 70.07317073, 267.92682927]]))
